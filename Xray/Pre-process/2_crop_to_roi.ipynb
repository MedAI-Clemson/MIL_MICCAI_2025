# %%
import json
import pandas as pd
from PIL import Image
import numpy as np

# %%
roi_data_path = '../data/roi_export-2022-09-20T01 40 52.606Z.json' 
nifti_meta_path = '../data/nifti.csv'
cropped_image_path = '../data/cropped_images/'
cropped_meta_path = '../data/cropped_image_metadata.csv'

# %% [markdown]
# # Parse label json objects

# %%
with open(roi_data_path, 'r') as f:
    data = json.load(f)

# %%
roi_data_path
# Out:
# '../data/roi_export-2022-09-20T01 40 52.606Z.json'

# %%
data[0]
# Out:
# {'ID': 'cl6bg0tybail807zngn1b2qxb',
#  'DataRow ID': 'cl66q51xv10yt075bct7wfefq',
#  'Labeled Data': 'https://fast-videos.s3.us-east-2.amazonaws.com/phf/cobra_prelim_set/AN00001_Y_VIEW_4.jpg',
#  'Label': {'objects': [{'featureId': 'cl6bg0zib00013s6gt29fdw2g',
#     'schemaId': 'cl62esinv16is07152vpv1y33',
#     'color': '#1CE6FF',
#     'title': 'ROI',
#     'value': 'roi',
#     'bbox': {'top': 401, 'left': 505, 'height': 996, 'width': 863},
#     'instanceURI': 'https://api.labelbox.com/masks/feature/cl6bg0zib00013s6gt29fdw2g?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjanIyYzk4MXhrN29kMDc5NzM0M2ZtaXN5Iiwib3JnYW5pemF0aW9uSWQiOiJjanIyYzk3cmRxN3RyMDczNzI1bDYxY29lIiwiaWF0IjoxNjYzNjM4MDUyLCJleHAiOjE2NjYyMzAwNTJ9.p3SsCyEzh51ZAWvMUjkP54mw4gKpn39NuAmYcw468Xs'}],
#   'classifications': [{'featureId': 'cl6nvkvow00032869zcod0eeb',
#     'schemaId': 'cl6nvcrzg0g0p08z71ayt4rm7',
#     'scope': 'global',
#     'title': 'View',
#     'value': 'view',
#     'answer': {'featureId': 'cl6nvkvow000228699hr5qvel',
#      'schemaId': 'cl6nvcrzg0g0s08z77um3fvw4',
#      'title': 'Y',
#      'value': 'y'}}],
#   'relationships': []},
#  'Created By': 'sbf@clemson.edu',
#  'Project Name': 'PHF Classification -- COBRA Prelim',
#  'Created At': '2022-08-02T00:30:15.000Z',
#  'Updated At': '2022-08-10T17:18:33.000Z',
#  'Seconds to Label': 41.477,
#  'Seconds to Review': 9.503,
#  'Seconds to Create': 31.974,
#  'External ID': 'AN00001_Y_VIEW_4',
#  'Global Key': None,
#  'Agreement': -1,
#  'Benchmark Agreement': -1,
#  'Benchmark ID': None,
#  'Dataset Name': 'lbx_data.json',
#  'Reviews': [{'id': 'cl6nvl45b0jgy08y1aol2deec',
#    'score': 1,
#    'createdAt': '2022-08-10 17:18:35.000000',
#    'createdBy': 'cjr2c981xk7od0797343fmisy'}],
#  'View Label': 'https://editor.labelbox.com?project=cl62chict0mcr071hfh992hpl&label=cl6bg0tybail807zngn1b2qxb',
#  'Has Open Issues': 0,
#  'Skipped': False,
#  'DataRow Workflow Info': {'Workflow History': []}}

# %%
data[0]['Label']
# Out:
# {'objects': [{'featureId': 'cl6bg0zib00013s6gt29fdw2g',
#    'schemaId': 'cl62esinv16is07152vpv1y33',
#    'color': '#1CE6FF',
#    'title': 'ROI',
#    'value': 'roi',
#    'bbox': {'top': 401, 'left': 505, 'height': 996, 'width': 863},
#    'instanceURI': 'https://api.labelbox.com/masks/feature/cl6bg0zib00013s6gt29fdw2g?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjanIyYzk4MXhrN29kMDc5NzM0M2ZtaXN5Iiwib3JnYW5pemF0aW9uSWQiOiJjanIyYzk3cmRxN3RyMDczNzI1bDYxY29lIiwiaWF0IjoxNjYzNjM4MDUyLCJleHAiOjE2NjYyMzAwNTJ9.p3SsCyEzh51ZAWvMUjkP54mw4gKpn39NuAmYcw468Xs'}],
#  'classifications': [{'featureId': 'cl6nvkvow00032869zcod0eeb',
#    'schemaId': 'cl6nvcrzg0g0p08z71ayt4rm7',
#    'scope': 'global',
#    'title': 'View',
#    'value': 'view',
#    'answer': {'featureId': 'cl6nvkvow000228699hr5qvel',
#     'schemaId': 'cl6nvcrzg0g0s08z77um3fvw4',
#     'title': 'Y',
#     'value': 'y'}}],
#  'relationships': []}

# %%
def parse_roi(lab):
    
    result = dict()
    
    # get external id
    result['external_id'] = lab['External ID']
    
    # get bounding box
    objects = lab['Label']['objects']
    if len(objects)>1:
        print("Warning: more than one bounding box. Using the first box.")    
        bbox = objects[0]['bbox']
    elif len(objects)==0:
        bbox=None
    else:
        bbox = objects[0]['bbox']
    
    if bbox is not None:
        for k,v in bbox.items():
            result[f'bbox_{k}'] = v
    
    # get classifications:
    for c in lab['Label']['classifications']:
        if c['value'] == 'special_notes':
            for a in c['answers']:
                result[a['value']] = True
            
        elif c['value'] == 'optional_notes':
            result['note'] = c['answer']
        
    return result

# %%
df = pd.DataFrame([parse_roi(d) for d in data])
df
# Out:
#                  external_id  bbox_top  bbox_left  bbox_height  bbox_width  \
# 0           AN00001_Y_VIEW_4     401.0      505.0        996.0       863.0
# 1              AN00010__1001     277.0      688.0        631.0       393.0
# 2              AN00010__1002    1098.0      642.0        844.0       825.0
# 3              AN00010__1004     809.0      353.0        347.0       409.0
# 4              AN00010__1005     693.0     1087.0        349.0       389.0
# ...                      ...       ...        ...          ...         ...
# 1141    AN00099_Shoulder_R_2     588.0      813.0        532.0       454.0
# 1142    AN00099_Shoulder_R_3      69.0     1491.0        521.0       455.0
# 1143      AN00001_AXILLARY_3    1363.0     1834.0        726.0       698.0
# 1144  AN00001_EXT_ROTATION_2     726.0      677.0        796.0       721.0
# 1145  AN00001_INT_ROTATION_1     754.0      626.0        693.0       660.0
#
#                          note poor_quality not_a_phf_view brightness_flipped
# 0                         NaN          NaN            NaN                NaN
# 1                         NaN          NaN            NaN                NaN
# 2     bad quality image, drop         True            NaN                NaN
# 3      not the shoulder, drop          NaN           True                NaN
# 4          Not shoulder, skip          NaN           True                NaN
# ...                       ...          ...            ...                ...
# 1141                      NaN          NaN            NaN                NaN
# 1142                      NaN          NaN            NaN                NaN
# 1143                      NaN          NaN            NaN               True
# 1144                      NaN          NaN            NaN               True
# 1145                      NaN          NaN            NaN               True
#
# [1146 rows x 9 columns]

# %%
# impute False flags
df.brightness_flipped = df.brightness_flipped.fillna(False)
df.poor_quality = df.poor_quality.fillna(False)
df.not_a_phf_view = df.not_a_phf_view.fillna(False)

# %%
# drop rows with missing bbox
df = df.dropna(subset=['bbox_top', 'bbox_left', 'bbox_height', 'bbox_width'])

# %%
df[~df.note.isna()]
# Out:
#                         external_id  bbox_top  bbox_left  bbox_height  \
# 2                     AN00010__1002    1098.0      642.0        844.0
# 3                     AN00010__1004     809.0      353.0        347.0
# 4                     AN00010__1005     693.0     1087.0        349.0
# 5                AN00100_AXILLARY_4     462.0     1043.0        614.0
# 12             AN00102_Shoulder_R_2     418.0     1000.0        596.0
# 31             AN00108_Shoulder_L_3     396.0      473.0        521.0
# 54             AN00116_Shoulder_R_1     665.0      783.0        536.0
# 55             AN00116_Shoulder_R_2     797.0      743.0        470.0
# 59            AN00117_AP_SHOULDER_5     375.0      708.0       1010.0
# 60            AN00117_AP_SHOULDER_6     595.0      568.0        504.0
# 77                AN00123_Y_VIEW_18     626.0      986.0        544.0
# 102            AN00131_Shoulder_L_3     311.0      826.0        557.0
# 115                    AN00136_AP_1     579.0     1053.0        499.0
# 116                    AN00136_AP_5     525.0      753.0        491.0
# 163                    AN00148_AP_4    1005.0     1266.0        715.0
# 200           AN00157_Shoulder_L_1a     727.0      446.0        681.0
# 222           AN00162_Shoulder_L_1a     651.0      649.0        648.0
# 503  AN00246_SHOULDER_AP_INTERNAL_2     568.0      783.0        680.0
# 844               AN00354_Grashey_3     931.0      993.0        468.0
# 931           AN00380_LAT_HUMERUS_2     487.0     1589.0        521.0
# 946          AN00385_Shoulder_AP_1b     377.0      566.0        424.0
# 980             AN00049_AXILLARY_12     118.0      332.0        959.0
# 983               AN00049_Y_VIEW_11     387.0      442.0        582.0
#
#      bbox_width                                note  poor_quality  \
# 2         825.0             bad quality image, drop          True
# 3         409.0              not the shoulder, drop         False
# 4         389.0                  Not shoulder, skip         False
# 5         389.0  image rotation makes box angle odd         False
# 12        542.0                   low quality image          True
# 31        514.0                   hard to make out           True
# 54        490.0               strange shapes appear         False
# 55        465.0               strange shapes appear         False
# 59        829.0                       poor contrast          True
# 60        520.0                        low contrast          True
# 77        483.0                       poor contrast          True
# 102       474.0                   odd shapes appear         False
# 115       458.0                       poor contrast          True
# 116       468.0                       poor contrast          True
# 163       578.0                       poor contrast          True
# 200       597.0             not sure about this one         False
# 222       574.0                 hardware in picture         False
# 503       445.0                        weird shapes         False
# 844       417.0                 odd shape appearing         False
# 931       458.0               some shapes appearing         False
# 946       377.0                                             False
# 980       626.0                 hardware in humerus         False
# 983       553.0                hardware in shoulder         False
#
#      not_a_phf_view  brightness_flipped
# 2             False               False
# 3              True               False
# 4              True               False
# 5             False               False
# 12            False               False
# 31            False               False
# 54            False               False
# 55            False               False
# 59            False                True
# 60            False                True
# 77            False                True
# 102           False               False
# 115           False                True
# 116           False                True
# 163           False               False
# 200           False               False
# 222           False               False
# 503           False               False
# 844           False                True
# 931           False               False
# 946           False               False
# 980           False                True
# 983           False                True

# %%
df.brightness_flipped.value_counts()
# Out:
# False    755
# True     361
# Name: brightness_flipped, dtype: int64

# %%
df.poor_quality.value_counts()
# Out:
# False    1044
# True       72
# Name: poor_quality, dtype: int64

# %%
df.not_a_phf_view.value_counts()
# Out:
# False    1112
# True        4
# Name: not_a_phf_view, dtype: int64

# %% [markdown]
# # join on image data

# %%
df_nifti = pd.read_csv(nifti_meta_path)
df_nifti['external_id'] = df_nifti['PATIENT_ID'] + '_' + df_nifti['FILENAME_VIEW']

# %%
df_wide = df.merge(df_nifti, how='inner', on='external_id')
assert len(df_wide) == len(df), "Data loss when merging nifti metadata with ROI data. ROI data should be a subset of nifti metadata."

# %%
df_wide.head()
# Out:
#         external_id  bbox_top  bbox_left  bbox_height  bbox_width  \
# 0  AN00001_Y_VIEW_4     401.0      505.0        996.0       863.0
# 1     AN00010__1001     277.0      688.0        631.0       393.0
# 2     AN00010__1002    1098.0      642.0        844.0       825.0
# 3     AN00010__1004     809.0      353.0        347.0       409.0
# 4     AN00010__1005     693.0     1087.0        349.0       389.0
#
#                       note  poor_quality  not_a_phf_view  brightness_flipped  \
# 0                      NaN         False           False               False
# 1                      NaN         False           False               False
# 2  bad quality image, drop          True           False               False
# 3   not the shoulder, drop         False            True               False
# 4       Not shoulder, skip         False            True               False
#
#   PATIENT_ID                                          FULL_PATH FILENAME_VIEW  \
# 0    AN00001  /zfs/wficai/xray/xray//Images/AN (1)/Y_VIEW_4.nii      Y_VIEW_4
# 1    AN00010    /zfs/wficai/xray/xray//Images/AN (10)/_1001.nii         _1001
# 2    AN00010    /zfs/wficai/xray/xray//Images/AN (10)/_1002.nii         _1002
# 3    AN00010    /zfs/wficai/xray/xray//Images/AN (10)/_1004.nii         _1004
# 4    AN00010    /zfs/wficai/xray/xray//Images/AN (10)/_1005.nii         _1005
#
#     MIN    MAX DATA_TYPE  WIDTH  HEIGHT  NUM_CHANNELS    ROI  \
# 0  1139  26177     int16   2328    2928             1  False
# 1  5398  16383     int16   2142    1855             1  False
# 2  6035  11921     int16   2119    2300             1  False
# 3  4875  16383     int16   1571    2499             1  False
# 4     0  16383     int16   2630    1477             1  False
#
#                                             JPG_PATH
# 0  /home/xiaofey/xray/xray-master/data/exported_j...
# 1  /home/xiaofey/xray/xray-master/data/exported_j...
# 2  /home/xiaofey/xray/xray-master/data/exported_j...
# 3  /home/xiaofey/xray/xray-master/data/exported_j...
# 4  /home/xiaofey/xray/xray-master/data/exported_j...

# %%
df_wide
# Out:
#                  external_id  bbox_top  bbox_left  bbox_height  bbox_width  \
# 0           AN00001_Y_VIEW_4     401.0      505.0        996.0       863.0
# 1              AN00010__1001     277.0      688.0        631.0       393.0
# 2              AN00010__1002    1098.0      642.0        844.0       825.0
# 3              AN00010__1004     809.0      353.0        347.0       409.0
# 4              AN00010__1005     693.0     1087.0        349.0       389.0
# ...                      ...       ...        ...          ...         ...
# 1111    AN00099_Shoulder_R_2     588.0      813.0        532.0       454.0
# 1112    AN00099_Shoulder_R_3      69.0     1491.0        521.0       455.0
# 1113      AN00001_AXILLARY_3    1363.0     1834.0        726.0       698.0
# 1114  AN00001_EXT_ROTATION_2     726.0      677.0        796.0       721.0
# 1115  AN00001_INT_ROTATION_1     754.0      626.0        693.0       660.0
#
#                          note  poor_quality  not_a_phf_view  \
# 0                         NaN         False           False
# 1                         NaN         False           False
# 2     bad quality image, drop          True           False
# 3      not the shoulder, drop         False            True
# 4          Not shoulder, skip         False            True
# ...                       ...           ...             ...
# 1111                      NaN         False           False
# 1112                      NaN         False           False
# 1113                      NaN         False           False
# 1114                      NaN         False           False
# 1115                      NaN         False           False
#
#       brightness_flipped PATIENT_ID  \
# 0                  False    AN00001
# 1                  False    AN00010
# 2                  False    AN00010
# 3                  False    AN00010
# 4                  False    AN00010
# ...                  ...        ...
# 1111               False    AN00099
# 1112               False    AN00099
# 1113                True    AN00001
# 1114                True    AN00001
# 1115                True    AN00001
#
#                                               FULL_PATH   FILENAME_VIEW  \
# 0     /zfs/wficai/xray/xray//Images/AN (1)/Y_VIEW_4.nii        Y_VIEW_4
# 1       /zfs/wficai/xray/xray//Images/AN (10)/_1001.nii           _1001
# 2       /zfs/wficai/xray/xray//Images/AN (10)/_1002.nii           _1002
# 3       /zfs/wficai/xray/xray//Images/AN (10)/_1004.nii           _1004
# 4       /zfs/wficai/xray/xray//Images/AN (10)/_1005.nii           _1005
# ...                                                 ...             ...
# 1111  /zfs/wficai/xray/xray//Images/AN (99)/Shoulder...    Shoulder_R_2
# 1112  /zfs/wficai/xray/xray//Images/AN (99)/Shoulder...    Shoulder_R_3
# 1113  /zfs/wficai/xray/xray//Images/AN (1)/AXILLARY_...      AXILLARY_3
# 1114  /zfs/wficai/xray/xray//Images/AN (1)/EXT_ROTAT...  EXT_ROTATION_2
# 1115  /zfs/wficai/xray/xray//Images/AN (1)/INT_ROTAT...  INT_ROTATION_1
#
#         MIN    MAX DATA_TYPE  WIDTH  HEIGHT  NUM_CHANNELS    ROI  \
# 0      1139  26177     int16   2328    2928             1  False
# 1      5398  16383     int16   2142    1855             1  False
# 2      6035  11921     int16   2119    2300             1  False
# 3      4875  16383     int16   1571    2499             1  False
# 4         0  16383     int16   2630    1477             1  False
# ...     ...    ...       ...    ...     ...           ...    ...
# 1111      0  30823     int16   2931    1614             1  False
# 1112      0  29055     int16   2163    1022             1  False
# 1113  10244  26573     int16   2928    2328             1  False
# 1114   1421  27093     int16   2928    2328             1  False
# 1115   2272  27356     int16   2928    2328             1  False
#
#                                                JPG_PATH
# 0     /home/xiaofey/xray/xray-master/data/exported_j...
# 1     /home/xiaofey/xray/xray-master/data/exported_j...
# 2     /home/xiaofey/xray/xray-master/data/exported_j...
# 3     /home/xiaofey/xray/xray-master/data/exported_j...
# 4     /home/xiaofey/xray/xray-master/data/exported_j...
# ...                                                 ...
# 1111  /home/xiaofey/xray/xray-master/data/exported_j...
# 1112  /home/xiaofey/xray/xray-master/data/exported_j...
# 1113  /home/xiaofey/xray/xray-master/data/exported_j...
# 1114  /home/xiaofey/xray/xray-master/data/exported_j...
# 1115  /home/xiaofey/xray/xray-master/data/exported_j...
#
# [1116 rows x 20 columns]

# %%
from PIL import Image, ImageOps

def crop_image(row):
    # read in image
    img = Image.open(row['JPG_PATH'].replace('/Documents/Code/', '/PycharmProjects/'))
    
    # crop 
    l = row['bbox_left']
    t = row['bbox_top']
    r = row['bbox_left'] + row['bbox_width']
    b = row['bbox_top'] + row['bbox_height']
    img = img.crop((l, t, r, b))
    
    # reverse negatives
    if row['brightness_flipped']:
        img = ImageOps.invert(img)
    
    # save cropped image
    save_path = cropped_image_path + row['JPG_PATH'].split('/')[-1]
    img.save(save_path)
    
    return save_path

# %%
for i, row in df_wide.iterrows():
    print(f"Processing image {i+1}/{len(df)}.", end='\r')
    
    # only process if a valid phf view of good quality
    if not (row['poor_quality'] or row['not_a_phf_view']):
        df_wide.loc[i,'CROPPED_IMAGE_PATH'] = crop_image(row)
# Out:
# Processing image 1116/1116.

# %%
df_wide.head()
# Out:
#         external_id  bbox_top  bbox_left  bbox_height  bbox_width  \
# 0  AN00001_Y_VIEW_4     401.0      505.0        996.0       863.0
# 1     AN00010__1001     277.0      688.0        631.0       393.0
# 2     AN00010__1002    1098.0      642.0        844.0       825.0
# 3     AN00010__1004     809.0      353.0        347.0       409.0
# 4     AN00010__1005     693.0     1087.0        349.0       389.0
#
#                       note  poor_quality  not_a_phf_view  brightness_flipped  \
# 0                      NaN         False           False               False
# 1                      NaN         False           False               False
# 2  bad quality image, drop          True           False               False
# 3   not the shoulder, drop         False            True               False
# 4       Not shoulder, skip         False            True               False
#
#   PATIENT_ID  ... FILENAME_VIEW   MIN    MAX  DATA_TYPE WIDTH  HEIGHT  \
# 0    AN00001  ...      Y_VIEW_4  1139  26177      int16  2328    2928
# 1    AN00010  ...         _1001  5398  16383      int16  2142    1855
# 2    AN00010  ...         _1002  6035  11921      int16  2119    2300
# 3    AN00010  ...         _1004  4875  16383      int16  1571    2499
# 4    AN00010  ...         _1005     0  16383      int16  2630    1477
#
#    NUM_CHANNELS    ROI                                           JPG_PATH  \
# 0             1  False  /home/xiaofey/xray/xray-master/data/exported_j...
# 1             1  False  /home/xiaofey/xray/xray-master/data/exported_j...
# 2             1  False  /home/xiaofey/xray/xray-master/data/exported_j...
# 3             1  False  /home/xiaofey/xray/xray-master/data/exported_j...
# 4             1  False  /home/xiaofey/xray/xray-master/data/exported_j...
#
#                             CROPPED_IMAGE_PATH
# 0  ../data/cropped_images/AN00001_Y_VIEW_4.jpg
# 1     ../data/cropped_images/AN00010__1001.jpg
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
# [5 rows x 21 columns]

# %%
df_wide.to_csv(cropped_meta_path, index=None)

# %%
cropped_meta_path
# Out:
# '../data/cropped_image_metadata.csv'
